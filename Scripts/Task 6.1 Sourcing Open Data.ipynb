# %%
# Importing libraries

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
# Setting path
path = r'C:\Users\Bhati\OneDrive\Desktop\CF\Data Analytics Immersion\Achievement 6\25-May-2023 Germany Rent Analysis'

# %%
# Importing Orginal Data Set
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'immo_data.csv'),  index_col = False)

# %%
df.head()
# Out:
#                 regio1  serviceCharge                     heatingType  \
# 0  Nordrhein_Westfalen         245.00                 central_heating
# 1      Rheinland_Pfalz         134.00  self_contained_central_heating
# 2              Sachsen         255.00                   floor_heating
# 3              Sachsen          58.15                district_heating
# 4               Bremen         138.00  self_contained_central_heating
#
#   telekomTvOffer  telekomHybridUploadSpeed  newlyConst  balcony  picturecount  \
# 0  ONE_YEAR_FREE                       NaN       False    False             6
# 1  ONE_YEAR_FREE                       NaN       False     True             8
# 2  ONE_YEAR_FREE                      10.0        True     True             8
# 3  ONE_YEAR_FREE                       NaN       False     True             9
# 4            NaN                       NaN       False     True            19
#
#    pricetrend  telekomUploadSpeed  ...               regio2  \
# ...

# %%
df.describe()
# Out:
#        serviceCharge  telekomHybridUploadSpeed   picturecount     pricetrend  \
# count  261941.000000                   45020.0  268850.000000  267018.000000
# mean      151.206113                      10.0       9.791958       3.389001
# std       308.295790                       0.0       6.408399       1.964874
# min         0.000000                      10.0       0.000000     -12.330000
# 25%        95.000000                      10.0       6.000000       2.000000
# 50%       135.000000                      10.0       9.000000       3.390000
# 75%       190.000000                      10.0      13.000000       4.570000
# max    146118.000000                      10.0     121.000000      14.920000
#
#        telekomUploadSpeed     totalRent  yearConstructed       scoutId  \
# count       235492.000000  2.283330e+05    211805.000000  2.688500e+05
# mean            28.804928  9.013315e+02      1966.400590  1.069697e+08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   regio1                    268850 non-null  object
#  1   serviceCharge             261941 non-null  float64
#  2   heatingType               223994 non-null  object
#  3   telekomTvOffer            236231 non-null  object
#  4   telekomHybridUploadSpeed  45020 non-null   float64
#  5   newlyConst                268850 non-null  bool
#  6   balcony                   268850 non-null  bool
#  7   picturecount              268850 non-null  int64
#  8   pricetrend                267018 non-null  float64
#  9   telekomUploadSpeed        235492 non-null  float64
#  10  totalRent                 228333 non-null  float64
#  11  yearConstructed           211805 non-null  float64
#  12  scoutId                   268850 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# regio1                           0
# serviceCharge                 6909
# heatingType                  44856
# telekomTvOffer               32619
# telekomHybridUploadSpeed    223830
# newlyConst                       0
# balcony                          0
# picturecount                     0
# pricetrend                    1832
# telekomUploadSpeed           33358
# totalRent                    40517
# yearConstructed              57045
# scoutId                          0
# noParkSpaces                175798
# firingTypes                  56964
# hasKitchen                       0
# geo_bln                          0
# cellar                           0
# yearConstructedRange         57045
# baseRent                         0
# houseNumber                  71018
# livingSpace                      0
# geo_krs                          0
# condition                    68489
# interiorQual                112665
# petsAllowed                 114573
# street                           0
# ...

# %%
df.shape
# Out:
# (268850, 49)

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %% [markdown]
# No Duplicates Found

# %%
#Checking for missing data percentage
percent_missing = (df.isnull().sum()/df.shape[0]) * 100

# %%
percent_missing.sort_values()
# Out:
# regio1                       0.000000
# regio3                       0.000000
# regio2                       0.000000
# livingSpaceRange             0.000000
# garden                       0.000000
# noRoomsRange                 0.000000
# noRooms                      0.000000
# geo_plz                      0.000000
# baseRentRange                0.000000
# lift                         0.000000
# street                       0.000000
# geo_krs                      0.000000
# livingSpace                  0.000000
# baseRent                     0.000000
# cellar                       0.000000
# geo_bln                      0.000000
# date                         0.000000
# balcony                      0.000000
# scoutId                      0.000000
# newlyConst                   0.000000
# hasKitchen                   0.000000
# picturecount                 0.000000
# pricetrend                   0.681421
# serviceCharge                2.569834
# description                  7.344988
# ...

# %%
# Removing Columns with more than 25% missing values
df_new = df.drop(['streetPlain','houseNumber','numberOfFloors','thermalChar','interiorQual','petsAllowed','noParkSpaces','heatingCosts','lastRefurbish','energyEfficiencyClass','electricityKwhPrice','electricityBasePrice', 'telekomHybridUploadSpeed'], axis=1)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 268850 entries, 0 to 268849
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   regio1                268850 non-null  object
#  1   serviceCharge         261941 non-null  float64
#  2   heatingType           223994 non-null  object
#  3   telekomTvOffer        236231 non-null  object
#  4   newlyConst            268850 non-null  bool
#  5   balcony               268850 non-null  bool
#  6   picturecount          268850 non-null  int64
#  7   pricetrend            267018 non-null  float64
#  8   telekomUploadSpeed    235492 non-null  float64
#  9   totalRent             228333 non-null  float64
#  10  yearConstructed       211805 non-null  float64
#  11  scoutId               268850 non-null  int64
#  12  firingTypes           211886 non-null  object
#  13  hasKitchen            268850 non-null  bool
# ...

# %%
# Removing unecessary columns
df_new_2 = df_new.drop(['description', 'facilities', 'geo_bln', 'scoutId'], axis=1)

# %%
df_new_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 268850 entries, 0 to 268849
# Data columns (total 32 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   regio1                268850 non-null  object
#  1   serviceCharge         261941 non-null  float64
#  2   heatingType           223994 non-null  object
#  3   telekomTvOffer        236231 non-null  object
#  4   newlyConst            268850 non-null  bool
#  5   balcony               268850 non-null  bool
#  6   picturecount          268850 non-null  int64
#  7   pricetrend            267018 non-null  float64
#  8   telekomUploadSpeed    235492 non-null  float64
#  9   totalRent             228333 non-null  float64
#  10  yearConstructed       211805 non-null  float64
#  11  firingTypes           211886 non-null  object
#  12  hasKitchen            268850 non-null  bool
#  13  cellar                268850 non-null  bool
# ...

# %%
df_new_2.describe()
# Out:
#        serviceCharge   picturecount     pricetrend  telekomUploadSpeed  \
# count  261941.000000  268850.000000  267018.000000       235492.000000
# mean      151.206113       9.791958       3.389001           28.804928
# std       308.295790       6.408399       1.964874           16.337151
# min         0.000000       0.000000     -12.330000            1.000000
# 25%        95.000000       6.000000       2.000000           10.000000
# 50%       135.000000       9.000000       3.390000           40.000000
# 75%       190.000000      13.000000       4.570000           40.000000
# max    146118.000000     121.000000      14.920000          100.000000
#
#           totalRent  yearConstructed  yearConstructedRange      baseRent  \
# count  2.283330e+05    211805.000000         211805.000000  2.688500e+05
# mean   9.013315e+02      1966.400590              3.714544  6.941294e+02
# std    3.323833e+04        46.992207              2.738134  1.953602e+04
# ...

# %%
df_new_2.shape
# Out:
# (268850, 32)

# %%
# keeping the data only with the year < 2023 and greater than 1800
df_new_3 = df_new_2[(df_new_2['yearConstructed']<2023) & (df_new_2['yearConstructed']>1800)]

# %%
df_new_3.shape
# Out:
# (210771, 32)

# %%
df_new_3.describe()
# Out:
#        serviceCharge   picturecount     pricetrend  telekomUploadSpeed  \
# count  207189.000000  210771.000000  209264.000000       183913.000000
# mean      152.693281       9.844789       3.407776           28.853067
# std       343.973837       6.415198       1.970708           16.343018
# min         0.000000       0.000000     -12.330000            1.000000
# 25%        95.000000       6.000000       2.000000           10.000000
# 50%       136.000000       9.000000       3.390000           40.000000
# 75%       190.000000      13.000000       4.570000           40.000000
# max    146118.000000     121.000000      14.920000          100.000000
#
#           totalRent  yearConstructed  yearConstructedRange       baseRent  \
# count  1.781630e+05    210771.000000         210771.000000  210771.000000
# mean   9.198564e+02      1968.011520              3.727671     656.799635
# std    3.733945e+04        38.460485              2.738128     585.755721
# ...

# %%
filterdf = df_new_3[df_new_3['noRooms']>6]

# %%
filterdf
# Out:
#                         regio1  serviceCharge       heatingType  \
# 1384                   Sachsen            NaN               NaN
# 1537                    Berlin         368.76  district_heating
# 1648                    Hessen        1200.00   central_heating
# 2052                    Berlin         740.00  district_heating
# 2097                   Sachsen         150.00   central_heating
# ...                        ...            ...               ...
# 266809                  Berlin        2100.00       gas_heating
# 266998  Mecklenburg_Vorpommern         370.00   central_heating
# 267721                  Berlin         424.00   central_heating
# 268062                  Bayern         230.00   central_heating
# 268141       Baden_Württemberg         491.00   central_heating
#
#        telekomTvOffer  newlyConst  balcony  picturecount  pricetrend  \
# 1384    ONE_YEAR_FREE       False    False            21        3.03
# ...

# %%
#Removing rows with more than 6 rooms
df_new_4 = df_new_3[(df_new_3['noRooms']<6)]

# %%
df_new_4.describe()
# Out:
#        serviceCharge   picturecount     pricetrend  telekomUploadSpeed  \
# count  205841.000000  209357.000000  207863.000000       182684.000000
# mean      151.386718       9.810969       3.403656           28.861493
# std       343.922272       6.377977       1.969397           16.341448
# min         0.000000       0.000000     -12.330000            1.000000
# 25%        95.000000       6.000000       2.000000           10.000000
# 50%       135.000000       9.000000       3.390000           40.000000
# 75%       190.000000      13.000000       4.570000           40.000000
# max    146118.000000     121.000000      14.920000          100.000000
#
#           totalRent  yearConstructed  yearConstructedRange       baseRent  \
# count  1.770120e+05    209357.000000         209357.000000  209357.000000
# mean   9.111603e+02      1968.090319              3.730499     648.598644
# std    3.746019e+04        38.402241              2.738369     564.191187
# ...

# %%
filter2 = df_new_4[df_new_4['floor']>50]

# %%
filter2
# Out:
#                 regio1  serviceCharge                     heatingType  \
# 3272           Sachsen         118.85                     gas_heating
# 8138            Berlin         170.00  self_contained_central_heating
# 56203          Sachsen         167.90                district_heating
# 56384          Sachsen         149.16                     gas_heating
# 58923          Sachsen         202.22                     gas_heating
# 75178          Sachsen         199.13                district_heating
# 105184         Sachsen         160.00                district_heating
# 105426         Sachsen         152.77                     gas_heating
# 123619  Sachsen_Anhalt         157.50                     gas_heating
# 134609         Sachsen         143.11                district_heating
# 152214          Berlin         395.00                             NaN
# 156661          Berlin         151.65                             NaN
# ...

# %%
#Removing rows with more than 50 floors
df_new_5 = df_new_4[(df_new_4['floor']<50)]

# %%
df_new_5.describe()
# Out:
#        serviceCharge   picturecount     pricetrend  telekomUploadSpeed  \
# count  171527.000000  173641.000000  172376.000000       152413.000000
# mean      150.367846       9.876849       3.385090           28.949315
# std       374.414418       6.403043       1.999464           16.302906
# min         0.000000       0.000000     -12.330000            1.000000
# 25%        93.335000       6.000000       1.960000           10.000000
# 50%       135.000000       9.000000       3.330000           40.000000
# 75%       187.000000      13.000000       4.550000           40.000000
# max    146118.000000     121.000000      14.920000          100.000000
#
#           totalRent  yearConstructed  yearConstructedRange       baseRent  \
# count  1.490330e+05    173641.000000         173641.000000  173641.000000
# mean   9.183985e+02      1967.372694              3.639860     639.202118
# std    4.082364e+04        37.936111              2.676462     571.969853
# ...

# %%
filter3 = df_new_5[df_new_5['livingSpace'] > 1000]
filter3
# Out:
#                      regio1  serviceCharge       heatingType telekomTvOffer  \
# 51540           Brandenburg         146.00   central_heating  ONE_YEAR_FREE
# 151184               Bayern         115.00   central_heating  ONE_YEAR_FREE
# 202205  Nordrhein_Westfalen         107.00       oil_heating  ONE_YEAR_FREE
# 215900              Sachsen          60.00   central_heating  ONE_YEAR_FREE
# 222457  Nordrhein_Westfalen          99.35   central_heating  ONE_YEAR_FREE
# 223187               Hessen         128.25  district_heating  ONE_YEAR_FREE
# 243713  Nordrhein_Westfalen       25000.00     floor_heating  ONE_YEAR_FREE
#
#         newlyConst  balcony  picturecount  pricetrend  telekomUploadSpeed  \
# 51540        False    False             8        4.33                 2.4
# 151184       False    False            23        6.09                40.0
# 202205       False     True            11        3.29                40.0
# ...

# %%
#Removing rows with more than 1000 m2 living sapce
df_new_6 = df_new_5[(df_new_5['livingSpace']<1000)]

# %%
df_new_6.describe()
# Out:
#        serviceCharge   picturecount     pricetrend  telekomUploadSpeed  \
# count  171520.000000  173634.000000  172369.000000       152406.000000
# mean      150.224404       9.876804       3.385048           28.949548
# std       369.582960       6.403068       1.999466           16.302756
# min         0.000000       0.000000     -12.330000            1.000000
# 25%        93.320000       6.000000       1.960000           10.000000
# 50%       135.000000       9.000000       3.330000           40.000000
# 75%       187.000000      13.000000       4.550000           40.000000
# max    146118.000000     121.000000      14.920000          100.000000
#
#           totalRent  yearConstructed  yearConstructedRange       baseRent  \
# count  1.490300e+05    173634.000000         173634.000000  173634.000000
# mean   9.183922e+02      1967.372277              3.639846     638.512957
# std    4.082405e+04        37.936430              2.676472     495.078805
# ...

# %%
Filter4 = df_new_6[(df_new_6['serviceCharge']>df_new_6['totalRent'])]
Filter4
# Out:
#                      regio1  serviceCharge                     heatingType  \
# 1119                Sachsen          105.0                 central_heating
# 1883    Nordrhein_Westfalen           75.0            night_storage_heater
# 4209                Sachsen          100.0                 central_heating
# 5035                Sachsen          100.0                 central_heating
# 5739                Sachsen           75.0  self_contained_central_heating
# ...                     ...            ...                             ...
# 260830              Sachsen          105.0                 central_heating
# 261685              Sachsen          130.0                 central_heating
# 261940  Nordrhein_Westfalen          220.0                 central_heating
# 266209  Nordrhein_Westfalen           80.0  self_contained_central_heating
# 268067    Baden_Württemberg          350.0                district_heating
#
# ...

# %%
Filter5 = df_new_6[(df_new_6['totalRent'] == 0)]
Filter5
# Out:
#                      regio1  serviceCharge                     heatingType  \
# 1119                Sachsen          105.0                 central_heating
# 1883    Nordrhein_Westfalen           75.0            night_storage_heater
# 4209                Sachsen          100.0                 central_heating
# 5035                Sachsen          100.0                 central_heating
# 5739                Sachsen           75.0  self_contained_central_heating
# ...                     ...            ...                             ...
# 260830              Sachsen          105.0                 central_heating
# 261685              Sachsen          130.0                 central_heating
# 261940  Nordrhein_Westfalen          220.0                 central_heating
# 266209  Nordrhein_Westfalen           80.0  self_contained_central_heating
# 268067    Baden_Württemberg          350.0                district_heating
#
# ...

# %%
#Removing rows with totalRent as 0
df_new_7 = df_new_6[(df_new_6['totalRent']>0)]

# %%
df_new_7.describe()
# Out:
#        serviceCharge   picturecount     pricetrend  telekomUploadSpeed  \
# count  147756.000000  148833.000000  147707.000000       130592.000000
# mean      151.013732       9.948493       3.396458           29.066234
# std       395.893922       6.427019       2.036860           16.269111
# min         0.000000       0.000000     -12.330000            1.000000
# 25%        95.000000       6.000000       1.930000           10.000000
# 50%       135.000000       9.000000       3.340000           40.000000
# 75%       189.000000      13.000000       4.590000           40.000000
# max    146118.000000     109.000000      14.920000          100.000000
#
#           totalRent  yearConstructed  yearConstructedRange       baseRent  \
# count  1.488330e+05    148833.000000         148833.000000  148833.000000
# mean   9.196078e+02      1966.911888              3.627186     636.892150
# std    4.085104e+04        38.320811              2.675579     491.782088
# ...

# %%
df_new_7.isnull().sum()
# Out:
# regio1                      0
# serviceCharge            1077
# heatingType             17548
# telekomTvOffer          17888
# newlyConst                  0
# balcony                     0
# picturecount                0
# pricetrend               1126
# telekomUploadSpeed      18241
# totalRent                   0
# yearConstructed             0
# firingTypes             18766
# hasKitchen                  0
# cellar                      0
# yearConstructedRange        0
# baseRent                    0
# livingSpace                 0
# geo_krs                     0
# condition               30998
# street                      0
# lift                        0
# baseRentRange               0
# typeOfFlat              19738
# geo_plz                     0
# noRooms                     0
# floor                       0
# noRoomsRange                0
# garden                      0
# livingSpaceRange            0
# regio2                      0
# regio3                      0
# ...

# %%
df_new_7.shape
# Out:
# (148833, 32)

# %%
# Replacing missing values with NaN
df_new_8 = df_new_7.fillna('NaN')

# %%
df_new_9 = df_new_8.rename(columns={'Unnamed: 0':'Index','regio1':'State', 'geo_plz':'Pincode', 'geo_krs':'City', 
                       'heatingType':'Heating_type','telekomTvOffer':'TV_offer', 'newlyConst':'Newly_built', 
                       'balcony':'Balcony', 'yearConstructed':'Year_constructed', 'hasKitchen':'Kitchen', 'cellar':'Cellar',
                       'livingSpace':'Area(m2)','condition':'House_condition','lift':'Lift','typeOfFlat':'Flat_type', 
                       'floor':'Floor','noRooms':'Rooms', 'garden':'Garden', 'serviceCharge':'Maintenance_fee',
                       'pricetrend':'Price_trend', 'baseRent':'Base_rent', 'picturecount':'Picture_count','regio2': 'District',
                       'regio3': 'City/town', 'telekomUploadSpeed': 'Internet_speed', 'totalRent': 'Total_Rent','firingTypes': 'Energy_Source'})

# %%
df_new_9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148833 entries, 0 to 268847
# Data columns (total 32 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   State                 148833 non-null  object
#  1   Maintenance_fee       148833 non-null  object
#  2   Heating_type          148833 non-null  object
#  3   TV_offer              148833 non-null  object
#  4   Newly_built           148833 non-null  bool
#  5   Balcony               148833 non-null  bool
#  6   Picture_count         148833 non-null  int64
#  7   Price_trend           148833 non-null  object
#  8   Internet_speed        148833 non-null  object
#  9   Total_Rent            148833 non-null  float64
#  10  Year_constructed      148833 non-null  float64
#  11  Energy_Source         148833 non-null  object
#  12  Kitchen               148833 non-null  bool
#  13  Cellar                148833 non-null  bool
# ...

# %%
df_new_9.shape
# Out:
# (148833, 32)

# %%
# Export Cleaned Data
df_new_9.to_csv(os.path.join(path, '02 Data','Prepared Data', 'Cleaned_Germany_Rent_Data.csv'))
